# %%
min_age_at_school = 5
hammad_age = input("how old is hammad? ")
print("hammad can go to school", min_age_at_school == int(hammad_age))
# Out:
# hammad can go to school False

# %% [markdown]
# we are learning python with datascience

# %%
samosa = ("alo","pyaz","mirch","dhania","anardana","maida","namak","qeema")
samosa
# Out:
# ('alo', 'pyaz', 'mirch', 'dhania', 'anardana', 'maida', 'namak', 'qeema')

# %%
2+7
# Out:
# 9

# %%
3-5
# Out:
# -2

# %% [markdown]
# # libraries used in this dataScience course
# 1. pandas
# 2. numpy
# 3. matplotlib
# 4. seaborn
# 5. plotly
# 6. scipy
# 7. scikit-learn
# 8. keras
# 9. stremlit

# %%
import plotly.express as px
data = dict(
    number=[39, 27.4, 20.6, 11, 2],
    stage=["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"])
fig = px.funnel(data, x='number', y='stage')
fig.show()

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")
